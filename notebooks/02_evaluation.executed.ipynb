# %% [markdown]
# # 02 - Final Evaluation and Model Comparison
#
# This notebook summarizes final evaluation artifacts generated by `src/evaluate.py` and `src/interpret.py`.
#
# It is intentionally report-focused:
# - load canonical metrics JSON files,
# - compare model metrics side-by-side,
# - review confusion matrices and training curves,
# - highlight pneumonia recall (sensitivity) as the primary screening metric.
#
# All metrics and figures are read from `results/` outputs (no duplicate training/evaluation logic in notebook cells).

# %%
from pathlib import Path
import json
import os
import subprocess
import sys
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Markdown, Image

REPO_NAME = "CS-171-Chest-X-Ray-Medical-Diagnosis"
REPO_URL = "https://github.com/jenilkathrotia/CS-171-Chest-X-Ray-Medical-Diagnosis.git"
REPO_BRANCH = "part-3"
IS_COLAB = "google.colab" in sys.modules

if IS_COLAB:
    colab_repo = Path("/content") / REPO_NAME
    if not colab_repo.exists():
        subprocess.run(
            ["git", "clone", "--branch", REPO_BRANCH, REPO_URL, str(colab_repo)],
            check=True,
        )
    os.chdir(colab_repo)
    subprocess.run(["git", "fetch", "origin", REPO_BRANCH], check=False)
    subprocess.run(["git", "checkout", REPO_BRANCH], check=False)
    subprocess.run(["git", "pull", "origin", REPO_BRANCH], check=False)


def resolve_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "notebooks").exists():
            return candidate

    colab_candidate = Path("/content") / REPO_NAME
    if (colab_candidate / "src").exists():
        return colab_candidate

    raise FileNotFoundError(
        f"Could not locate project root from cwd={start}. Expected a directory containing src/ and notebooks/."
    )


cwd = Path.cwd()
project_root = resolve_project_root(cwd)
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

if IS_COLAB and (project_root / "requirements.txt").exists():
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "-r", str(project_root / "requirements.txt")],
        check=False,
    )

RESULTS_DIR = project_root / "results"
METRICS_DIR = RESULTS_DIR / "metrics"
PLOTS_DIR = RESULTS_DIR / "plots"
CM_DIR = RESULTS_DIR / "confusion_matrices"

metric_paths = {
    "custom_cnn": METRICS_DIR / "custom_cnn_metrics.json",
    "densenet121": METRICS_DIR / "densenet121_metrics.json",
}

for name, path in metric_paths.items():
    if not path.exists():
        raise FileNotFoundError(
            f"Missing metrics file for {name}: {path}. Run `python -m src.evaluate --model {name} --data-dir <path-to-chest_xray>` first."
        )

print("cwd:", cwd)
print("project_root:", project_root)
print("Using results directory:", RESULTS_DIR)
print("Metrics files:")
for name, path in metric_paths.items():
    print(f"  - {name}: {path}")
# Out:
# cwd: C:\Users\aidan\Downloads\School\CS 171\Project\CS-171-Chest-X-Ray-Medical-Diagnosis\notebooks
# project_root: C:\Users\aidan\Downloads\School\CS 171\Project\CS-171-Chest-X-Ray-Medical-Diagnosis
# Using results directory: C:\Users\aidan\Downloads\School\CS 171\Project\CS-171-Chest-X-Ray-Medical-Diagnosis\results
# Metrics files:
#   - custom_cnn: C:\Users\aidan\Downloads\School\CS 171\Project\CS-171-Chest-X-Ray-Medical-Diagnosis\results\metrics\custom_cnn_metrics.json
#   - densenet121: C:\Users\aidan\Downloads\School\CS 171\Project\CS-171-Chest-X-Ray-Medical-Diagnosis\results\metrics\densenet121_metrics.json

# %%
def load_metrics(path: Path) -> dict:
    return json.loads(path.read_text(encoding="utf-8"))

rows = []
for model_name, path in metric_paths.items():
    payload = load_metrics(path)
    report = payload["classification_report"]
    rows.append(
        {
            "model": model_name,
            "accuracy": payload["accuracy"],
            "precision_normal": report["NORMAL"]["precision"],
            "recall_normal": report["NORMAL"]["recall"],
            "f1_normal": report["NORMAL"]["f1-score"],
            "precision_pneumonia": report["PNEUMONIA"]["precision"],
            "recall_pneumonia": report["PNEUMONIA"]["recall"],
            "f1_pneumonia": report["PNEUMONIA"]["f1-score"],
            "macro_f1": report["macro avg"]["f1-score"],
            "weighted_f1": report["weighted avg"]["f1-score"],
            "num_samples": payload["num_samples"],
            "checkpoint_epoch_meta": payload.get("checkpoint_metadata", {}).get("epoch"),
        }
    )

comparison = pd.DataFrame(rows).sort_values("model").reset_index(drop=True)

display(Markdown("## Final Metric Comparison"))
display(comparison)

display(Markdown("### Clinical Priority: Pneumonia Recall (Sensitivity)"))
for _, row in comparison.iterrows():
    display(Markdown(f"- **{row['model']}** pneumonia recall: **{row['recall_pneumonia']:.4f}**"))
# Out:
# ## Final Metric Comparison
#          model  accuracy  precision_normal  recall_normal  f1_normal  \
# 0   custom_cnn  0.833333          0.828283       0.700855   0.759259
# 1  densenet121  0.887821          0.976744       0.717949   0.827586
#
#    precision_pneumonia  recall_pneumonia  f1_pneumonia  macro_f1  weighted_f1  \
# 0             0.835681          0.912821      0.872549  0.815904     0.830065
# 1             0.853982          0.989744      0.916865  0.872225     0.883385
#
#    num_samples  checkpoint_epoch_meta
# 0          624                      1
# 1          624                      6
# ### Clinical Priority: Pneumonia Recall (Sensitivity)
# - **custom_cnn** pneumonia recall: **0.9128**
# - **densenet121** pneumonia recall: **0.9897**

# %%
display(Markdown("## Confusion Matrices"))
for model_name in ["custom_cnn", "densenet121"]:
    img_path = CM_DIR / f"{model_name}_confusion_matrix.png"
    display(Markdown(f"### {model_name}"))
    if img_path.exists():
        display(Image(filename=str(img_path)))
    else:
        print("Missing:", img_path)

display(Markdown("## Training Curves"))
for img_name in [
    "custom_cnn_training_curves.png",
    "densenet121_training_curves.png",
    "model_comparison_validation_curves.png",
]:
    img_path = PLOTS_DIR / img_name
    display(Markdown(f"### {img_name}"))
    if img_path.exists():
        display(Image(filename=str(img_path)))
    else:
        print("Missing:", img_path)

display(Markdown("## Interpretation Notes"))

best_idx = comparison["accuracy"].idxmax()
best = comparison.iloc[best_idx]
other = comparison.drop(index=best_idx).iloc[0]

interpretation_lines = [
    f"- **Best overall model:** `{best['model']}` with accuracy **{best['accuracy']:.4f}** "
    f"and pneumonia recall **{best['recall_pneumonia']:.4f}**.",
    f"- **Baseline model:** `{other['model']}` reaches accuracy **{other['accuracy']:.4f}** "
    f"and pneumonia recall **{other['recall_pneumonia']:.4f}**.",
    f"- NORMAL recall: best={best['recall_normal']:.4f}, other={other['recall_normal']:.4f}; "
    "neither model is perfectly balanced, but both correctly identify most NORMAL cases.",
    "- Clinical priority is pneumonia sensitivity (catching positive cases). "
    f"`{best['model']}` is preferred for screening because its sensitivity is higher and "
    "false-negative count is lower (see confusion matrices above).",
    "- Metrics here are derived directly from `results/metrics/*.json`; "
    "regenerate by re-running `src/evaluate.py` if checkpoints change.",
]

display(Markdown("\n".join(interpretation_lines)))
# Out:
# ## Confusion Matrices
# ### custom_cnn
# ### densenet121
# ## Training Curves
# ### custom_cnn_training_curves.png
# ### densenet121_training_curves.png
# ### model_comparison_validation_curves.png
# ## Interpretation Notes
# - **Best overall model:** `densenet121` with accuracy **0.8878** and pneumonia recall **0.9897**.
# - **Baseline model:** `custom_cnn` reaches accuracy **0.8333** and pneumonia recall **0.9128**.
# - NORMAL recall: best=0.7179, other=0.7009; neither model is perfectly balanced, but both correctly identify most NORMAL cases.
# - Clinical priority is pneumonia sensitivity (catching positive cases). `densenet121` is preferred for screening because its sensitivity is higher and false-negative count is lower (see confusion matrices above).
# - Metrics here are derived directly from `results/metrics/*.json`; regenerate by re-running `src/evaluate.py` if checkpoints change.
